# %% [markdown]
# # Welcome to a lab_🐼s!
#
# Last week, you did amazing work in setting up your computer to do Data Science!  Let's now do Data Science on your computer for the first time!
#
# A few tips to remember:
#
# - Refer to your **lecture notebook** and the **pandas cheat sheet** to help you out with the code!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 0: Your Lab Group!
#
# We find it's best when you're programming with a group of people who you can help out and can help you out!
#
# - A key part of Data Science is being able to communicate about your work.  If you are the best programmer in the world, but no one uses your code, then the code you're writing is not getting run.  By learning strong communication skills, you will be able to explain your code, and the underlying data science concepts, to everyone -- data scientists and non-scientists alike!
#
# - Every lab you will need to complete some parts of the lab with your group.  There will be both "group discussions" and "individual reflections" as part of every lab.

# %% [markdown]
# ## Create Your Group
#
# If you have not done so already, **RIGHT NOW** find *(ideally)* two other people to make a group of **two, three, or four** people.   *(We find groups of three work the best, but you can be a group of two or four -- no solo groups, and no groups of five!*)
#
# - If you're at a group of five, split into a group of two and a group of three.  You can still help each other as a larger group, but the group questions should be answered in your smaller group of 2-4 people.
#
# Once you have your group **introduce yourselves to each other! :)**

# %% [markdown]
# ## Record Your Group
#
# Since you know Python, edit the following cell to add strings about your group:

# %%
# First, meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Hanjia"
ca1_name = "Alyssa"
ca2_name = "Aehi"


# As part of your introduction, learn your lab partner's name, major, and
# learn something new about them that you never knew!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "William Yeh"
partner1_netid = "wy16"
partner1_major = "Buisness Major"

partner2_name = "Seongwook Min"
partner2_netid = "sm116"
partner2_major = "Information science"

partner3_name = "Kei Yamato"
partner3_netid = "kyamato2"
partner3_major = "Geography and Information science"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: 🧑‍🤝‍🧑 Hello Dataset!

# %% [markdown]
# Last week, we explored the "Party Dataset" that you created.  We will continue to use the Party Dataset all semester long, but we want even more datasets -- and we want you to come up with the questions!
#
# - You will come up with questions to ask the class for the "Hello Dataset"!
# - *(This was originally on lab_intro, so you can use your answers from there if you got to this part!  If you did not, work with your group right now!)*

# %% [markdown]
# ## Hello Dataset Overview
#
# Your lab homework will be to fill out a class-wide "Hello Survey".  Right now, with your group, you will come up some of the questions that should be on this survey *(and you will do analysis on your questions next week!)*.
#
# With your group, come up with four questions below!  Before you get started, a few notes:
#
# - The survey will be **not be anonymous** and the results will be shared with the class to do analysis on, so you should **only ask questions you feel comfortable to share with the class**.
# - **Questions that are inappropriate** for a classroom environment will be thrown out and you won't earn lab credit points for any question we throw out.  (Keep everything PG/PG-13.)
# - You are going to submit **one set of questions for your whole group**.  You must decide on the questions together.

# %% [markdown]
# ## Q1: Question with a Binary Response
#
# A question with a **binary response** is a question that has only two answers.  For example:
# - *Do you prefer cats or dogs?*
# - *Were you born in Illinois?*
#
# With your group (you must all decide on a single question together), come up with a question that you think will have **exactly 50%/50%** split between the two binary outcomes.  *(The question that gets closest to 50%/50% will get extra credit!)*

# %% [markdown]
# **What is your binary question?**
#
# Do you use Windows or Mac?

# %% [markdown]
# **Why do you think this is a good question?  Write at least two complete sentences on why you believe your question will have a 50%/50% split.**
#
# This is a good question because the professor ask this question during lecture and it was 50 and 50.

# %% [markdown]
# ## Q2: Question with a Numeric Response
#
# A question with a **numeric response** requires a number for an answer.  For example:
#
# - *What is your height?*
# - *What day were you born?*
#
# With your group (you must all decide on a single question together), come up with a question and a prediction on what you think the most frequent answer will be to your question.

# %% [markdown]
# **What is your numeric question?**
#
# How many fingers do you have?

# %% [markdown]
# **What do you think the most frequent answer will be?**
#
# 10

# %% [markdown]
# **Why do you think this answer will be the most frequent answer?  Write at least one complete sentences on why you believe that it will be the most frequent answer.**
#
# 10 will be the most frequent the average human have 10 fingers.

# %% [markdown]
# ## Q3: Question with a (non-numeric) Textual Response
#
# A question with a (non-numeric) **textual response** requires a word or two for an answer.  For example:
#
# - *What is your favorite sport to play?*
# - *What is the location of your favorite trip/vacation?*
#
# With your group (you must all decide on a single question together), come up with a question where at least two members of your group share the same answer.

# %% [markdown]
# **What is your textual response question?**
#
# What is your favorite ice cream?

# %% [markdown]
# **What is the shared answer between your group?  Do you also share this answer (if not, what's your answer to the question)?**
#
# 50% percent was cookies and cream and 50% was fruity falvors like mango or lemon

# %% [markdown]
# ## Q4: Open Question
#
# One final question -- no restrictions on the format!  Is there a great question your group discussed that you did not get to use one of the first three questions but you want to know the classes' answer?

# %% [markdown]
# **What is your final question for the whole class?**
#
# Why did you go to UIUC?

# %% [markdown]
# ## Submit Your Questions to Your TA
#
# Your lab TAs will be grading your lab notebook for your full responses, but we want to make sure to get the survey with your questions out to everyone ASAP!
#
# - Pick one member of your group as the "question submitter".
# - If you're the question submitter, complete this Google Form for your group (requires @illinois.edu login): https://forms.gle/p1HvVZFT1jeSWRKL9

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: Importing the Course Catalog Dataset
#
# In lecture, you learned we will use the `pandas` **library** for working with data.  Libraries are collections of functions and other objects that extend what Python can do by itself.  The `pandas` library is the most widely used library for data science.
#
# To use the `pandas` library, we must **import** it into your notebook.  In literally every lab, you will need to import the library just like we did in lecture -- import pandas as `pd` in the following cell:

# %%
# Write the code to import pandas as pd:
import pandas as pd

# %% [markdown]
# In lecture, you saw the "Course Catalog" dataset.  Using the `read_csv` function, load the course catalog dataset.  The URL for this dataset is:
# ```
# https://waf.cs.illinois.edu/discovery/course-catalog.csv
# ```

# %%
# Load the course catalog dataset into a variable named `df`:
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog.csv")

# %%
# Print out the contents of `df`:
df
# Out:
#        Year  Term YearTerm Subject  Number                          Name  \
# 0      2022  Fall  2022-fa     AAS     100  Intro Asian American Studies
# 1      2022  Fall  2022-fa     AAS     100  Intro Asian American Studies
# 2      2022  Fall  2022-fa     AAS     100  Intro Asian American Studies
# 3      2022  Fall  2022-fa     AAS     100  Intro Asian American Studies
# 4      2022  Fall  2022-fa     AAS     100  Intro Asian American Studies
# ...     ...   ...      ...     ...     ...                           ...
# 12638  2022  Fall  2022-fa    YDSH     101           Beginning Yiddish I
# 12639  2022  Fall  2022-fa    YDSH     104       Intermediate Yiddish II
# 12640  2022  Fall  2022-fa    ZULU     201             Elementary Zulu I
# 12641  2022  Fall  2022-fa    ZULU     202            Elementary Zulu II
# 12642  2022  Fall  2022-fa    ZULU     403           Intermediate Zulu I
#
#                                              Description Credit Hours  \
# 0      Interdisciplinary introduction to the basic co...     3 hours.
# 1      Interdisciplinary introduction to the basic co...     3 hours.
# 2      Interdisciplinary introduction to the basic co...     3 hours.
# 3      Interdisciplinary introduction to the basic co...     3 hours.
# 4      Interdisciplinary introduction to the basic co...     3 hours.
# ...                                                  ...          ...
# 12638  Course develops basic conversational and readi...     4 hours.
# 12639  Continuation of YDSH 103. Prerequisite: YDSH 1...     4 hours.
# 12640  Introduction to Zulu; emphasis on grammar, pro...     5 hours.
# 12641  Continuation of ZULU 201 with introduction of ...     5 hours.
# 12642  Survey of more advanced grammar; emphasis on i...     4 hours.
#
#                                             Section Info  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12638                                                NaN
# 12639  Prerequisite: YDSH 103 or equivalent placement...
# 12640  Same as AFST 251. Participation in the languag...
# 12641  Same as AFST 252. Participation in the languag...
# 12642  Same as AFST 451. 4 undergraduate hours. 4 gra...
#
#                                        Degree Attributes  ... Section Status  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 1      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 2      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 3      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 4      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# ...                                                  ...  ...            ...
# 12638                                                NaN  ...              A
# 12639                                                NaN  ...              A
# 12640                                                NaN  ...              A
# 12641                                                NaN  ...              A
# 12642                                                NaN  ...              A
#
#        Enrollment Status                   Type Type Code Start Time  \
# 0                   Open  Discussion/Recitation       DIS   09:00 AM
# 1                 Closed  Discussion/Recitation       DIS   10:00 AM
# 2                   Open  Discussion/Recitation       DIS   10:00 AM
# 3                 Closed  Discussion/Recitation       DIS   11:00 AM
# 4                   Open  Discussion/Recitation       DIS   11:00 AM
# ...                  ...                    ...       ...        ...
# 12638               Open                 Online       ONL   09:00 AM
# 12639               Open                 Online       ONL   01:00 PM
# 12640      CrossListOpen     Lecture-Discussion       LCD   ARRANGED
# 12641               Open     Lecture-Discussion       LCD   ARRANGED
# 12642      CrossListOpen     Lecture-Discussion       LCD   ARRANGED
#
#        End Time Days of Week Room                   Building  \
# 0      09:50 AM            F  313             Davenport Hall
# 1      10:50 AM            F  313             Davenport Hall
# 2      10:50 AM            F  143  Henry Administration Bldg
# 3      11:50 AM            F  313             Davenport Hall
# 4      11:50 AM            F  143  Henry Administration Bldg
# ...         ...          ...  ...                        ...
# 12638  10:20 AM           MT  NaN                        NaN
# 12639  02:20 PM           MT  NaN                        NaN
# 12640       NaN          NaN  NaN                        NaN
# 12641       NaN          NaN  NaN                        NaN
# 12642       NaN          NaN  NaN                        NaN
#
#                 Instructors
# 0           Lee, S;Zheng, R
# 1           Lee, S;Zheng, R
# 2            Lee, S;Shin, J
# 3                    Lee, S
# 4            Lee, S;Shin, J
# ...                     ...
# 12638             Butler, D
# 12639             Butler, D
# 12640  Gathogo, M;Saadah, E
# 12641  Gathogo, M;Saadah, E
# 12642  Gathogo, M;Saadah, E
#
# [12643 rows x 27 columns]

# %% [markdown]
# ## 🔬 Test Case Checkpoint 🔬
#
# Throughout the lab, we will have "checkpoints" at key points.  Most checkpoints will include **test cases** that verify that your notebook appears to be correct.
#
# - The test cases are **NOT** a guarantee that everything is perfect, but we try our very best to catch any common mistakes you might make!
# - If you see `AssertionError` error message when running the test case, we provide a helpful hint on what may not be correct.
# - If you see a party popper emoji and a message that all tests pass, you passed the checkpoint!
# - **Checkpoints** are a good time to check with your group to make everyone gets to the checkpoint together!

# %%
## == CHECKPOINT TEST CASES for Part 1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "Did you define a variable called df?"
assert( len(df) == 12643 ), "It looks like you did not import the correct dataset?"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: STAT / CS / IS Majors
#
# Data Science DISCOVERY is a unique course that is cross-listed across three departments: Statistics, Computer Science, and Information Sciences.  Let's explore courses from all three of those subjects!

# %% [markdown]
# ### Puzzle 3.1
#
# Select only the rows that have a `Subject` of `STAT`.  Assign this to the variable name `df_STAT` instead of the usual `df`.
# - Make sure your result contains only statistics courses!

# %%
df_STAT = df[df.Subject == "STAT"]
df_STAT
# Out:
#        Year  Term YearTerm Subject  Number                           Name  \
# 11890  2022  Fall  2022-fa    STAT     100                     Statistics
# 11891  2022  Fall  2022-fa    STAT     100                     Statistics
# 11892  2022  Fall  2022-fa    STAT     107         Data Science Discovery
# 11893  2022  Fall  2022-fa    STAT     107         Data Science Discovery
# 11894  2022  Fall  2022-fa    STAT     107         Data Science Discovery
# ...     ...   ...      ...     ...     ...                            ...
# 12025  2022  Fall  2022-fa    STAT     578           Topics in Statistics
# 12026  2022  Fall  2022-fa    STAT     590  Individual Study and Research
# 12027  2022  Fall  2022-fa    STAT     593                STAT Internship
# 12028  2022  Fall  2022-fa    STAT     593                STAT Internship
# 12029  2022  Fall  2022-fa    STAT     599                Thesis Research
#
#                                              Description    Credit Hours  \
# 11890  First course in probability and statistics at ...        3 hours.
# 11891  First course in probability and statistics at ...        3 hours.
# 11892  Data Science Discovery is the intersection of ...        4 hours.
# 11893  Data Science Discovery is the intersection of ...        4 hours.
# 11894  Data Science Discovery is the intersection of ...        4 hours.
# ...                                                  ...             ...
# 12025  May be repeated if topics vary. Prerequisite: ...        4 hours.
# 12026  Directed reading and research. Approved for le...   0 TO 8 hours.
# 12027  Supervised, off-campus experience in a field i...   0 TO 8 hours.
# 12028  Supervised, off-campus experience in a field i...   0 TO 8 hours.
# 12029  Approved for S/U grading only. May be repeated...  0 TO 16 hours.
#
#                                             Section Info  \
# 11890  Credit is not given for both STAT 100 and any ...
# 11891  Credit is not given for both STAT 100 and any ...
# 11892                         Same as CS 107 and IS 107.
# 11893                         Same as CS 107 and IS 107.
# 11894                         Same as CS 107 and IS 107.
# ...                                                  ...
# 12025  May be repeated if topics vary. Prerequisite: ...
# 12026  Approved for letter and S/U grading. May be re...
# 12027  Approved for letter and S/U grading. Prerequis...
# 12028  Approved for letter and S/U grading. Prerequis...
# 12029  Approved for S/U grading only. May be repeated...
#
#                       Degree Attributes  ... Section Status  \
# 11890  Quantitative Reasoning I course.  ...              A
# 11891  Quantitative Reasoning I course.  ...              A
# 11892  Quantitative Reasoning I course.  ...              A
# 11893  Quantitative Reasoning I course.  ...              A
# 11894  Quantitative Reasoning I course.  ...              A
# ...                                 ...  ...            ...
# 12025                               NaN  ...              A
# 12026                               NaN  ...              A
# 12027                               NaN  ...              A
# 12028                               NaN  ...              A
# 12029                               NaN  ...              A
#
#        Enrollment Status                   Type Type Code Start Time  \
# 11890             Closed     Lecture-Discussion       LCD   12:00 PM
# 11891             Closed                 Online       ONL   ARRANGED
# 11892      CrossListOpen                Lecture       LEC   11:00 AM
# 11893             Closed  Laboratory-Discussion       LBD   12:30 PM
# 11894             Closed  Laboratory-Discussion       LBD   12:30 PM
# ...                  ...                    ...       ...        ...
# 12025  Open (Restricted)     Lecture-Discussion        S0   12:00 PM
# 12026  Open (Restricted)      Independent Study       IND   ARRANGED
# 12027  Open (Restricted)             Internship       INT   ARRANGED
# 12028  Open (Restricted)             Internship       INT   ARRANGED
# 12029  Open (Restricted)      Independent Study       IND   ARRANGED
#
#        End Time Days of Week   Room            Building  \
# 11890  12:50 PM          MWF  THEAT        Lincoln Hall
# 11891       NaN          NaN    NaN                 NaN
# 11892  11:50 AM          MWF  THEAT        Lincoln Hall
# 11893  01:50 PM            W    209           Huff Hall
# 11894  01:50 PM            W   2101  Everitt Laboratory
# ...         ...          ...    ...                 ...
# 12025  12:50 PM          MWF  106B8    Engineering Hall
# 12026       NaN          NaN    NaN                 NaN
# 12027       NaN          NaN    NaN                 NaN
# 12028       NaN          NaN    NaN                 NaN
# 12029       NaN          NaN    NaN                 NaN
#
#                                              Instructors
# 11890                                        Flanagan, K
# 11891                                        Flanagan, K
# 11892                  Fagen-Ulmschneider, W;Flanagan, K
# 11893                                            Xing, Y
# 11894                                             Kiv, D
# ...                                                  ...
# 12025                                      Chatterjee, S
# 12026                                                NaN
# 12027  Chronopoulou, A;Glosemeyer, D;Lee, H;Shao, X;U...
# 12028  Chronopoulou, A;Glosemeyer, D;Lee, H;Shao, X;U...
# 12029                                                NaN
#
# [140 rows x 27 columns]

# %% [markdown]
# ### Puzzle 3.2
#
# Select only the rows that have a `Subject` of `CS`.  Assign this to the variable name `df_CS` instead of the usual `df`.
# - Make sure your result contains only computer science courses!

# %%
df_CS = df[df.Subject == "CS"]
df_CS
# Out:
#       Year  Term YearTerm Subject  Number                              Name  \
# 3349  2022  Fall  2022-fa      CS     100      Computer Science Orientation
# 3350  2022  Fall  2022-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3351  2022  Fall  2022-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3352  2022  Fall  2022-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3353  2022  Fall  2022-fa      CS     101  Intro Computing: Engrg &amp; Sci
# ...    ...   ...      ...     ...     ...                               ...
# 3731  2022  Fall  2022-fa      CS     598                    Special Topics
# 3732  2022  Fall  2022-fa      CS     598                    Special Topics
# 3733  2022  Fall  2022-fa      CS     598                    Special Topics
# 3734  2022  Fall  2022-fa      CS     598                    Special Topics
# 3735  2022  Fall  2022-fa      CS     599                   Thesis Research
#
#                                             Description    Credit Hours  \
# 3349  Introduction to Computer Science as a field an...        1 hours.
# 3350  Fundamental principles, concepts, and methods ...        3 hours.
# 3351  Fundamental principles, concepts, and methods ...        3 hours.
# 3352  Fundamental principles, concepts, and methods ...        3 hours.
# 3353  Fundamental principles, concepts, and methods ...        3 hours.
# ...                                                 ...             ...
# 3731  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3732  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3733  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3734  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3735    Approved for S/U grading only. May be repeated.  0 TO 16 hours.
#
#                                            Section Info  \
# 3349                                                NaN
# 3350  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3351  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3352  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3353  Prerequisite: One of MATH 220 or MATH 221 or M...
# ...                                                 ...
# 3731  May be repeated in the same or separate terms ...
# 3732  May be repeated in the same or separate terms ...
# 3733  May be repeated in the same or separate terms ...
# 3734  May be repeated in the same or separate terms ...
# 3735    Approved for S/U grading only. May be repeated.
#
#                       Degree Attributes  ... Section Status  \
# 3349                                NaN  ...              A
# 3350  Quantitative Reasoning II course.  ...              A
# 3351  Quantitative Reasoning II course.  ...              A
# 3352  Quantitative Reasoning II course.  ...              A
# 3353  Quantitative Reasoning II course.  ...              P
# ...                                 ...  ...            ...
# 3731                                NaN  ...              A
# 3732                                NaN  ...              A
# 3733                                NaN  ...              A
# 3734                                NaN  ...              A
# 3735                                NaN  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 3349  Open (Restricted)                Lecture       LEC   03:00 PM  03:50 PM
# 3350  Open (Restricted)     Lecture-Discussion       LCD   10:00 AM  10:50 AM
# 3351               Open  Laboratory-Discussion       LBD   01:00 PM  02:50 PM
# 3352               Open  Laboratory-Discussion       LBD   03:00 PM  04:50 PM
# 3353             Closed  Laboratory-Discussion       LBD   05:00 PM  06:50 PM
# ...                 ...                    ...       ...        ...       ...
# 3731             Closed     Lecture-Discussion       LCD   11:00 AM  12:15 PM
# 3732  Open (Restricted)     Lecture-Discussion        S5   11:00 AM  12:15 PM
# 3733  Open (Restricted)     Lecture-Discussion       S15   11:00 AM  12:15 PM
# 3734  Open (Restricted)                Lecture        L2   02:00 PM  03:15 PM
# 3735             Closed      Independent Study       IND   ARRANGED       NaN
#
#      Days of Week   Room                       Building            Instructors
# 3349            F  THEAT                   Lincoln Hall               Fleck, M
# 3350           MW    AUD          Foellinger Auditorium  Beckman, M;Tahboub, R
# 3351            M   L416    Digital Computer Laboratory  Beckman, M;Tahboub, R
# 3352            M   L416    Digital Computer Laboratory  Beckman, M;Tahboub, R
# 3353            M   L416    Digital Computer Laboratory  Beckman, M;Tahboub, R
# ...           ...    ...                            ...                    ...
# 3731           MW    403     Siebel Center for Comp Sci               Olson, L
# 3732           TR   1310    Digital Computer Laboratory              Ringer, T
# 3733           WF   1302     Siebel Center for Comp Sci                Chan, T
# 3734           WF   1035  Campus Instructional Facility                Cobb, C
# 3735          NaN    NaN                            NaN                    NaN
#
# [387 rows x 27 columns]

# %% [markdown]
# ### Puzzle 3.3
#
# Select only the rows that have a `Subject` of `IS`.  Assign this to the variable name `df_IS` instead of the usual `df`.
# - Make sure your result contains only information science courses!

# %%
df_IS = df[df.Subject == "IS"]
df_IS
# Out:
#       Year  Term YearTerm Subject  Number  \
# 6663  2022  Fall  2022-fa      IS     100
# 6664  2022  Fall  2022-fa      IS     100
# 6665  2022  Fall  2022-fa      IS     100
# 6666  2022  Fall  2022-fa      IS     100
# 6667  2022  Fall  2022-fa      IS     100
# ...    ...   ...      ...     ...     ...
# 6907  2022  Fall  2022-fa      IS     596
# 6908  2022  Fall  2022-fa      IS     597
# 6909  2022  Fall  2022-fa      IS     597
# 6910  2022  Fall  2022-fa      IS     597
# 6911  2022  Fall  2022-fa      IS     599
#
#                                                    Name  \
# 6663   Exploring the iSchool with a Human-Centered Lens
# 6664   Exploring the iSchool with a Human-Centered Lens
# 6665   Exploring the iSchool with a Human-Centered Lens
# 6666   Exploring the iSchool with a Human-Centered Lens
# 6667   Exploring the iSchool with a Human-Centered Lens
# ...                                                 ...
# 6907  Advanced Topics in Human-Centered Design &amp;...
# 6908  Advanced Topics in Data Analytics &amp; Data S...
# 6909  Advanced Topics in Data Analytics &amp; Data S...
# 6910  Advanced Topics in Data Analytics &amp; Data S...
# 6911                                    Thesis Research
#
#                                             Description    Credit Hours  \
# 6663  This course introduces students to the School ...        1 hours.
# 6664  This course introduces students to the School ...        1 hours.
# 6665  This course introduces students to the School ...        1 hours.
# 6666  This course introduces students to the School ...        1 hours.
# 6667  This course introduces students to the School ...        1 hours.
# ...                                                 ...             ...
# 6907  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6908  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6909  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6910  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6911  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info Degree Attributes  \
# 6663  Prerequisite: Restricted to Majors Only; First...               NaN
# 6664  Prerequisite: Restricted to Majors Only; First...               NaN
# 6665  Prerequisite: Restricted to Majors Only; First...               NaN
# 6666  Prerequisite: Restricted to Majors Only; First...               NaN
# 6667  Prerequisite: Restricted to Majors Only; First...               NaN
# ...                                                 ...               ...
# 6907  2 or 4 graduate hours. No professional credit....               NaN
# 6908  2 or 4 graduate hours. No professional credit....               NaN
# 6909  2 or 4 graduate hours. No professional credit....               NaN
# 6910  2 or 4 graduate hours. No professional credit....               NaN
# 6911  0 to 16 graduate hours. No professional credit...               NaN
#
#       ... Section Status           Enrollment Status                Type  \
# 6663  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6664  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6665  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6666  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6667  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# ...   ...            ...                         ...                 ...
# 6907  ...              A           Open (Restricted)              Online
# 6908  ...              A           Open (Restricted)  Lecture-Discussion
# 6909  ...              A           Open (Restricted)  Lecture-Discussion
# 6910  ...              A           Open (Restricted)              Online
# 6911  ...              A           Open (Restricted)   Independent Study
#
#      Type Code Start Time  End Time Days of Week Room  \
# 6663       LCD   09:30 AM  10:50 AM            T  126
# 6664       LCD   09:30 AM  10:50 AM            T  126
# 6665       LCD   02:00 PM  03:20 PM            R  126
# 6666       LCD   02:00 PM  03:20 PM            R  126
# 6667       LCD   01:00 PM  01:50 PM            R  126
# ...        ...        ...       ...          ...  ...
# 6907       ONL   01:00 PM  02:55 PM            M  NaN
# 6908        S1   09:00 AM  11:50 AM            M  131
# 6909        S2   09:00 AM  11:50 AM            W  126
# 6910       ONL   09:00 AM  10:55 AM            F  NaN
# 6911       IND   ARRANGED       NaN          NaN  NaN
#
#                             Building Instructors
# 6663  Grad Sch of Lib & Info Science   Newell, M
# 6664  Grad Sch of Lib & Info Science   Newell, M
# 6665  Grad Sch of Lib & Info Science   Newell, M
# 6666  Grad Sch of Lib & Info Science   Newell, M
# 6667  Grad Sch of Lib & Info Science   Newell, M
# ...                              ...         ...
# 6907                             NaN     Wang, D
# 6908  Grad Sch of Lib & Info Science   Weible, J
# 6909  Grad Sch of Lib & Info Science   Weible, J
# 6910                             NaN  Diesner, J
# 6911                             NaN         NaN
#
# [249 rows x 27 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES for Part 3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_CS' in vars() ), "Make certain to name the CS courses df_CS."
assert( 'df_STAT' in vars() ), "Make certain to name the STAT courses df_STAT."
assert( 'df_IS' in vars() ), "Make certain to name the IS courses df_IS."
assert( len(df_STAT[df_STAT.Subject != "STAT"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."
assert( len(df_CS[df_CS.Subject != "CS"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."
assert( len(df_IS[df_IS.Subject != "IS"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.4
#
# Looking at the output of the DataFrames for STAT, CS, and IS above, which subject offers the **fewest** course sections?  The **most** course sections?

# %% [markdown]
# STAT has the fewest courses
# CS has the most courses

# %% [markdown]
# ### Puzzle 3.5
#
# Looking at the output of the DataFrames for STAT, CS, and IS above, which subject has the highest numbered course?  Is there something similar about all of the highest numbered courses?  Write about what you observed!

# %% [markdown]
# All subjects have the same level because they all are Thesis Research.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 4: Your Major

# %% [markdown]
# In this part, you will be exploring **your major** using the Course Catalog dataset.
#
# - Use the primary subject of your **current major** (or, if you're undeclared, your intended major) for this section.
# - Your answers will be different than the rest of your group!

# %% [markdown]
# ### Puzzle 4.1:
#
# Select only the rows that have a `Subject` of your current/intended major.  Assign this to the variable name `mydf` instead of `df`:

# %%
mydf = df[df.Subject == "IS"]
mydf
# Out:
#       Year  Term YearTerm Subject  Number  \
# 6663  2022  Fall  2022-fa      IS     100
# 6664  2022  Fall  2022-fa      IS     100
# 6665  2022  Fall  2022-fa      IS     100
# 6666  2022  Fall  2022-fa      IS     100
# 6667  2022  Fall  2022-fa      IS     100
# ...    ...   ...      ...     ...     ...
# 6907  2022  Fall  2022-fa      IS     596
# 6908  2022  Fall  2022-fa      IS     597
# 6909  2022  Fall  2022-fa      IS     597
# 6910  2022  Fall  2022-fa      IS     597
# 6911  2022  Fall  2022-fa      IS     599
#
#                                                    Name  \
# 6663   Exploring the iSchool with a Human-Centered Lens
# 6664   Exploring the iSchool with a Human-Centered Lens
# 6665   Exploring the iSchool with a Human-Centered Lens
# 6666   Exploring the iSchool with a Human-Centered Lens
# 6667   Exploring the iSchool with a Human-Centered Lens
# ...                                                 ...
# 6907  Advanced Topics in Human-Centered Design &amp;...
# 6908  Advanced Topics in Data Analytics &amp; Data S...
# 6909  Advanced Topics in Data Analytics &amp; Data S...
# 6910  Advanced Topics in Data Analytics &amp; Data S...
# 6911                                    Thesis Research
#
#                                             Description    Credit Hours  \
# 6663  This course introduces students to the School ...        1 hours.
# 6664  This course introduces students to the School ...        1 hours.
# 6665  This course introduces students to the School ...        1 hours.
# 6666  This course introduces students to the School ...        1 hours.
# 6667  This course introduces students to the School ...        1 hours.
# ...                                                 ...             ...
# 6907  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6908  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6909  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6910  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6911  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info Degree Attributes  \
# 6663  Prerequisite: Restricted to Majors Only; First...               NaN
# 6664  Prerequisite: Restricted to Majors Only; First...               NaN
# 6665  Prerequisite: Restricted to Majors Only; First...               NaN
# 6666  Prerequisite: Restricted to Majors Only; First...               NaN
# 6667  Prerequisite: Restricted to Majors Only; First...               NaN
# ...                                                 ...               ...
# 6907  2 or 4 graduate hours. No professional credit....               NaN
# 6908  2 or 4 graduate hours. No professional credit....               NaN
# 6909  2 or 4 graduate hours. No professional credit....               NaN
# 6910  2 or 4 graduate hours. No professional credit....               NaN
# 6911  0 to 16 graduate hours. No professional credit...               NaN
#
#       ... Section Status           Enrollment Status                Type  \
# 6663  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6664  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6665  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6666  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6667  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# ...   ...            ...                         ...                 ...
# 6907  ...              A           Open (Restricted)              Online
# 6908  ...              A           Open (Restricted)  Lecture-Discussion
# 6909  ...              A           Open (Restricted)  Lecture-Discussion
# 6910  ...              A           Open (Restricted)              Online
# 6911  ...              A           Open (Restricted)   Independent Study
#
#      Type Code Start Time  End Time Days of Week Room  \
# 6663       LCD   09:30 AM  10:50 AM            T  126
# 6664       LCD   09:30 AM  10:50 AM            T  126
# 6665       LCD   02:00 PM  03:20 PM            R  126
# 6666       LCD   02:00 PM  03:20 PM            R  126
# 6667       LCD   01:00 PM  01:50 PM            R  126
# ...        ...        ...       ...          ...  ...
# 6907       ONL   01:00 PM  02:55 PM            M  NaN
# 6908        S1   09:00 AM  11:50 AM            M  131
# 6909        S2   09:00 AM  11:50 AM            W  126
# 6910       ONL   09:00 AM  10:55 AM            F  NaN
# 6911       IND   ARRANGED       NaN          NaN  NaN
#
#                             Building Instructors
# 6663  Grad Sch of Lib & Info Science   Newell, M
# 6664  Grad Sch of Lib & Info Science   Newell, M
# 6665  Grad Sch of Lib & Info Science   Newell, M
# 6666  Grad Sch of Lib & Info Science   Newell, M
# 6667  Grad Sch of Lib & Info Science   Newell, M
# ...                              ...         ...
# 6907                             NaN     Wang, D
# 6908  Grad Sch of Lib & Info Science   Weible, J
# 6909  Grad Sch of Lib & Info Science   Weible, J
# 6910                             NaN  Diesner, J
# 6911                             NaN         NaN
#
# [249 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.2:
#
# Select **five random courses** from your major, using `mydf` and pandas functions:

# %%
mydf.sample(n=5)
# Out:
#       Year  Term YearTerm Subject  Number  \
# 6794  2022  Fall  2022-fa      IS     477
# 6785  2022  Fall  2022-fa      IS     455
# 6729  2022  Fall  2022-fa      IS     236
# 6732  2022  Fall  2022-fa      IS     266
# 6704  2022  Fall  2022-fa      IS     199
#
#                                                  Name  \
# 6794  Data Management, Curation &amp; Reproducibility
# 6785                  Database Design and Prototyping
# 6729                   User Research &amp; Evaluation
# 6732                             Community Innovation
# 6704                       Undergraduate Open Seminar
#
#                                             Description   Credit Hours  \
# 6794  Addresses issues in Data Management, Curation ...  3 OR 4 hours.
# 6785  The course provides students with both theoret...       4 hours.
# 6729  This course will teach students about user res...       3 hours.
# 6732  How do communities contribute to transformativ...       3 hours.
# 6704  Undergraduate Open Seminar. Additional fees ma...  1 TO 5 hours.
#
#                                            Section Info Degree Attributes  \
# 6794  3 undergraduate hours. 4 graduate hours. Prere...               NaN
# 6785  4 undergraduate hours. 4 graduate hours. Prere...               NaN
# 6729  Prerequisite: IS 204, or IS 226, or equivalent...               NaN
# 6732                                  Same as MACS 266.               NaN
# 6704  Additional fees may apply. See Class Schedule....               NaN
#
#       ... Section Status           Enrollment Status                Type  \
# 6794  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6785  ...              A                      Closed              Online
# 6729  ...              A           Open (Restricted)  Lecture-Discussion
# 6732  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6704  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
#
#      Type Code Start Time  End Time Days of Week  Room  \
# 6794       LCD   12:30 PM  03:20 PM            R  1047
# 6785       ONL   07:00 PM  09:00 PM            W   NaN
# 6729       LCD   12:30 PM  01:50 PM           TR   162
# 6732       LCD   12:30 PM  01:50 PM           TR   323
# 6704        S1   01:00 PM  01:50 PM            W   126
#
#                             Building  Instructors
# 6794        Sidney Lu Mech Engr Bldg   Maemura, E
# 6785                             NaN       Uhe, A
# 6729              Education Building      Wang, Y
# 6732              Education Building  Batzloff, B
# 6704  Grad Sch of Lib & Info Science    Hodson, R
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.3:
#
# Select **the seven lowest numbered courses** from your major:

# %%
mydf.nsmallest(7,"Number")
# Out:
#       Year  Term YearTerm Subject  Number  \
# 6663  2022  Fall  2022-fa      IS     100
# 6664  2022  Fall  2022-fa      IS     100
# 6665  2022  Fall  2022-fa      IS     100
# 6666  2022  Fall  2022-fa      IS     100
# 6667  2022  Fall  2022-fa      IS     100
# 6668  2022  Fall  2022-fa      IS     100
# 6669  2022  Fall  2022-fa      IS     100
#
#                                                   Name  \
# 6663  Exploring the iSchool with a Human-Centered Lens
# 6664  Exploring the iSchool with a Human-Centered Lens
# 6665  Exploring the iSchool with a Human-Centered Lens
# 6666  Exploring the iSchool with a Human-Centered Lens
# 6667  Exploring the iSchool with a Human-Centered Lens
# 6668  Exploring the iSchool with a Human-Centered Lens
# 6669  Exploring the iSchool with a Human-Centered Lens
#
#                                             Description Credit Hours  \
# 6663  This course introduces students to the School ...     1 hours.
# 6664  This course introduces students to the School ...     1 hours.
# 6665  This course introduces students to the School ...     1 hours.
# 6666  This course introduces students to the School ...     1 hours.
# 6667  This course introduces students to the School ...     1 hours.
# 6668  This course introduces students to the School ...     1 hours.
# 6669  This course introduces students to the School ...     1 hours.
#
#                                            Section Info Degree Attributes  \
# 6663  Prerequisite: Restricted to Majors Only; First...               NaN
# 6664  Prerequisite: Restricted to Majors Only; First...               NaN
# 6665  Prerequisite: Restricted to Majors Only; First...               NaN
# 6666  Prerequisite: Restricted to Majors Only; First...               NaN
# 6667  Prerequisite: Restricted to Majors Only; First...               NaN
# 6668  Prerequisite: Restricted to Majors Only; First...               NaN
# 6669  Prerequisite: Restricted to Majors Only; First...               NaN
#
#       ... Section Status           Enrollment Status                Type  \
# 6663  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6664  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6665  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6666  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6667  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6668  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6669  ...              P                      Closed  Lecture-Discussion
#
#      Type Code Start Time  End Time Days of Week Room  \
# 6663       LCD   09:30 AM  10:50 AM            T  126
# 6664       LCD   09:30 AM  10:50 AM            T  126
# 6665       LCD   02:00 PM  03:20 PM            R  126
# 6666       LCD   02:00 PM  03:20 PM            R  126
# 6667       LCD   01:00 PM  01:50 PM            R  126
# 6668       LCD   01:00 PM  01:50 PM            R  126
# 6669       LCD   09:00 AM  09:50 AM            R  126
#
#                             Building Instructors
# 6663  Grad Sch of Lib & Info Science   Newell, M
# 6664  Grad Sch of Lib & Info Science   Newell, M
# 6665  Grad Sch of Lib & Info Science   Newell, M
# 6666  Grad Sch of Lib & Info Science   Newell, M
# 6667  Grad Sch of Lib & Info Science   Newell, M
# 6668  Grad Sch of Lib & Info Science   Newell, M
# 6669  Grad Sch of Lib & Info Science   Newell, M
#
# [7 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.4:
#
# Select **the nine highest numbered courses** from your major:

# %%
mydf.nlargest(9,"Number")
# Out:
#       Year  Term YearTerm Subject  Number  \
# 6911  2022  Fall  2022-fa      IS     599
# 6908  2022  Fall  2022-fa      IS     597
# 6909  2022  Fall  2022-fa      IS     597
# 6910  2022  Fall  2022-fa      IS     597
# 6907  2022  Fall  2022-fa      IS     596
# 6906  2022  Fall  2022-fa      IS     595
# 6904  2022  Fall  2022-fa      IS     594
# 6905  2022  Fall  2022-fa      IS     594
# 6902  2022  Fall  2022-fa      IS     593
#
#                                                    Name  \
# 6911                                    Thesis Research
# 6908  Advanced Topics in Data Analytics &amp; Data S...
# 6909  Advanced Topics in Data Analytics &amp; Data S...
# 6910  Advanced Topics in Data Analytics &amp; Data S...
# 6907  Advanced Topics in Human-Centered Design &amp;...
# 6906  Advanced Topics in Organization &amp; Represen...
# 6904           Advanced Topics in Management and Policy
# 6905           Advanced Topics in Management and Policy
# 6902  Advanced Topics in Preservation &amp; Tech Ser...
#
#                                             Description    Credit Hours  \
# 6911  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 6908  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6909  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6910  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6907  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6906  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6904  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6905  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6902  Variety of newly developed and advanced topics...   2 OR 4 hours.
#
#                                            Section Info Degree Attributes  \
# 6911  0 to 16 graduate hours. No professional credit...               NaN
# 6908  2 or 4 graduate hours. No professional credit....               NaN
# 6909  2 or 4 graduate hours. No professional credit....               NaN
# 6910  2 or 4 graduate hours. No professional credit....               NaN
# 6907  2 or 4 graduate hours. No professional credit....               NaN
# 6906  2 or 4 graduate hours. No professional credit....               NaN
# 6904  2 or 4 graduate hours. No professional credit....               NaN
# 6905  2 or 4 graduate hours. No professional credit....               NaN
# 6902  2 or 4 graduate hours. No professional credit....               NaN
#
#       ... Section Status  Enrollment Status                Type Type Code  \
# 6911  ...              A  Open (Restricted)   Independent Study       IND
# 6908  ...              A  Open (Restricted)  Lecture-Discussion        S1
# 6909  ...              A  Open (Restricted)  Lecture-Discussion        S2
# 6910  ...              A  Open (Restricted)              Online       ONL
# 6907  ...              A  Open (Restricted)              Online       ONL
# 6906  ...              A  Open (Restricted)              Online        E1
# 6904  ...              A  Open (Restricted)              Online       ONL
# 6905  ...              A  Open (Restricted)              Online        E1
# 6902  ...              A             Closed              Online        E1
#
#      Start Time  End Time Days of Week Room                        Building  \
# 6911   ARRANGED       NaN          NaN  NaN                             NaN
# 6908   09:00 AM  11:50 AM            M  131  Grad Sch of Lib & Info Science
# 6909   09:00 AM  11:50 AM            W  126  Grad Sch of Lib & Info Science
# 6910   09:00 AM  10:55 AM            F  NaN                             NaN
# 6907   01:00 PM  02:55 PM            M  NaN                             NaN
# 6906   04:00 PM  05:55 PM            R  NaN                             NaN
# 6904   03:00 PM  04:55 PM            W  NaN                             NaN
# 6905   07:00 PM  09:00 PM            M  NaN                             NaN
# 6902   05:00 PM  06:55 PM            M  NaN                             NaN
#
#          Instructors
# 6911             NaN
# 6908       Weible, J
# 6909       Weible, J
# 6910      Diesner, J
# 6907         Wang, D
# 6906      Charles, D
# 6904   Hinchliffe, L
# 6905  Mead-Harvey, B
# 6902        Abney, A
#
# [9 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.5:
#
# Select **a random sample of 10% of the courses** from your major:

# %%
mydf.sample(frac = 0.1)
# Out:
#       Year  Term YearTerm Subject  Number  \
# 6824  2022  Fall  2022-fa      IS     510
# 6687  2022  Fall  2022-fa      IS     107
# 6673  2022  Fall  2022-fa      IS     101
# 6745  2022  Fall  2022-fa      IS     389
# 6897  2022  Fall  2022-fa      IS     591
# 6854  2022  Fall  2022-fa      IS     549
# 6850  2022  Fall  2022-fa      IS     543
# 6804  2022  Fall  2022-fa      IS     497
# 6713  2022  Fall  2022-fa      IS     203
# 6749  2022  Fall  2022-fa      IS     400
# 6705  2022  Fall  2022-fa      IS     202
# 6667  2022  Fall  2022-fa      IS     100
# 6830  2022  Fall  2022-fa      IS     514
# 6851  2022  Fall  2022-fa      IS     544
# 6881  2022  Fall  2022-fa      IS     582
# 6726  2022  Fall  2022-fa      IS     206
# 6668  2022  Fall  2022-fa      IS     100
# 6690  2022  Fall  2022-fa      IS     107
# 6754  2022  Fall  2022-fa      IS     403
# 6688  2022  Fall  2022-fa      IS     107
# 6741  2022  Fall  2022-fa      IS     312
# 6807  2022  Fall  2022-fa      IS     501
# 6835  2022  Fall  2022-fa      IS     523
# 6811  2022  Fall  2022-fa      IS     504
# 6809  2022  Fall  2022-fa      IS     504
#
#                                                    Name  \
# 6824                 Libraries, Information and Society
# 6687                             Data Science Discovery
# 6673               Introduction to Information Sciences
# 6745                                  Independent Study
# 6897            Advanced Topics in Information Services
# 6854                                          Practicum
# 6850                               Digital Preservation
# 6804        Topics in Data Analytics &amp; Data Science
# 6713    Analytical Foundations for Information Problems
# 6749                                         Colloquium
# 6705                           Social Aspects Info Tech
# 6667   Exploring the iSchool with a Human-Centered Lens
# 6830                          Applied Business Research
# 6851  Administration &amp; Management of Libraries a...
# 6881                   Advanced Topics in Librarianship
# 6726  Introduction to Database Concepts &amp; Applic...
# 6668   Exploring the iSchool with a Human-Centered Lens
# 6690                             Data Science Discovery
# 6754                               Children's Materials
# 6688                             Data Science Discovery
# 6741                           Reading and Writing Data
# 6807                 Reference and Information Services
# 6835                          Preserving Info Resources
# 6811                 Sociotechnical Information Systems
# 6809                 Sociotechnical Information Systems
#
#                                             Description   Credit Hours  \
# 6824  Explores major issues in the library and infor...       4 hours.
# 6687         Same as CS 107 and STAT 107. See STAT 107.       4 hours.
# 6673  This course provides an introduction to the fi...       3 hours.
# 6745  Advanced individual study in a subject related...  0 TO 3 hours.
# 6897  Variety of newly developed and advanced topics...  1 TO 4 hours.
# 6854  Supervised field experience of professional-le...       2 hours.
# 6850  Examines current problems with and approaches ...       4 hours.
# 6804  Variety of newly developed and topics courses ...  2 TO 4 hours.
# 6713  A survey of mathematical topics for students i...       3 hours.
# 6749  Venue for presentation and discussion of resea...       1 hours.
# 6705  Explores the way in which information technolo...       3 hours.
# 6667  This course introduces students to the School ...       1 hours.
# 6830  As an experiential learning class, this course...       4 hours.
# 6851  Designed to explore the principles that govern...       4 hours.
# 6881  Variety of newly developed and advanced topics...  2 OR 4 hours.
# 6726  Introduction to database technology concepts a...       3 hours.
# 6668  This course introduces students to the School ...       1 hours.
# 6690         Same as CS 107 and STAT 107. See STAT 107.       4 hours.
# 6754  Evaluation, selection and use of books and oth...  2 TO 4 hours.
# 6688         Same as CS 107 and STAT 107. See STAT 107.       4 hours.
# 6741  Explores how we tell stories and make argument...       3 hours.
# 6807  Explores reference and information services in...       4 hours.
# 6835  Covers the broad range of library preservation...       4 hours.
# 6811  The character, success, and costs/benefits of ...       4 hours.
# 6809  The character, success, and costs/benefits of ...       4 hours.
#
#                                            Section Info  \
# 6824  4 graduate hours. No professional credit. Prer...
# 6687         Same as CS 107 and STAT 107. See STAT 107.
# 6673                                                NaN
# 6745  Approved for Letter and S/U grading. May be re...
# 6897  1 to 4 graduate hours. No professional credit....
# 6854  2 graduate hours. No professional credit. Appr...
# 6850          4 graduate hours. No professional credit.
# 6804  Additional fees may apply. See Class Schedule....
# 6713    Prerequisite: MATH 112 or Required ALEKS Score.
# 6749  0 or 1 undergraduate hours. 0 or 1 graduate ho...
# 6705                     Same as INFO 202 and MACS 202.
# 6667  Prerequisite: Restricted to Majors Only; First...
# 6830  4 graduate hours. No professional credit. May ...
# 6851          4 graduate hours. No professional credit.
# 6881  Additional fees may apply. See Class Schedule....
# 6726  Prerequisite: IS 205, or CS 101, or CS 105, or...
# 6668  Prerequisite: Restricted to Majors Only; First...
# 6690         Same as CS 107 and STAT 107. See STAT 107.
# 6754  3 undergraduate hours. 2 or 4 graduate hours. ...
# 6688         Same as CS 107 and STAT 107. See STAT 107.
# 6741                                                NaN
# 6807          4 graduate hours. No professional credit.
# 6835          4 graduate hours. No professional credit.
# 6811          4 graduate hours. No professional credit.
# 6809          4 graduate hours. No professional credit.
#
#                                       Degree Attributes  ... Section Status  \
# 6824                                                NaN  ...              A
# 6687                   Quantitative Reasoning I course.  ...              A
# 6673                 Social & Beh Sci - Soc Sci course.  ...              A
# 6745                                                NaN  ...              A
# 6897                                                NaN  ...              A
# 6854                                                NaN  ...              A
# 6850                                                NaN  ...              A
# 6804                                                NaN  ...              A
# 6713                  Quantitative Reasoning II course.  ...              A
# 6749                                                NaN  ...              A
# 6705                 Social & Beh Sci - Soc Sci course.  ...              A
# 6667                                                NaN  ...              A
# 6830                                                NaN  ...              A
# 6851                                                NaN  ...              A
# 6881                                                NaN  ...              A
# 6726                                                NaN  ...              A
# 6668                                                NaN  ...              A
# 6690                   Quantitative Reasoning I course.  ...              A
# 6754                                                NaN  ...              A
# 6688                   Quantitative Reasoning I course.  ...              A
# 6741  Advanced Composition, and Humanities - Lit & A...  ...              A
# 6807                                                NaN  ...              A
# 6835                                                NaN  ...              A
# 6811                                                NaN  ...              A
# 6809                                                NaN  ...              A
#
#                Enrollment Status                   Type Type Code Start Time  \
# 6824           Open (Restricted)     Lecture-Discussion       LCD   04:00 PM
# 6687               CrossListOpen  Laboratory-Discussion       LBD   09:30 AM
# 6673                      Closed  Discussion/Recitation       DIS   12:30 PM
# 6745           Open (Restricted)      Independent Study       IND   ARRANGED
# 6897                      Closed                 Online       ONL   ARRANGED
# 6854           Open (Restricted)      Independent Study       IND   ARRANGED
# 6850           Open (Restricted)                 Online       ONL   06:00 PM
# 6804  CrossListOpen (Restricted)                 Online       ONL   06:00 PM
# 6713                      Closed  Discussion/Recitation       DIS   10:00 AM
# 6749  CrossListOpen (Restricted)                 Online       ONL   12:00 PM
# 6705               CrossListOpen  Discussion/Recitation       DIS   08:00 AM
# 6667  CrossListOpen (Restricted)     Lecture-Discussion       LCD   01:00 PM
# 6830                      Closed     Lecture-Discussion       LCD   02:00 PM
# 6851           Open (Restricted)     Lecture-Discussion       LCD   04:00 PM
# 6881           Open (Restricted)                 Online       ONL   05:00 PM
# 6726                      Closed         Online Lecture       OLC   12:00 PM
# 6668  CrossListOpen (Restricted)     Lecture-Discussion       LCD   01:00 PM
# 6690                      Closed  Laboratory-Discussion       LBD   11:00 AM
# 6754                      Closed                 Online       ONL   05:00 PM
# 6688                      Closed  Laboratory-Discussion       LBD   09:30 AM
# 6741           Open (Restricted)     Lecture-Discussion       LCD   11:00 AM
# 6807           Open (Restricted)                 Online       ONL   05:00 PM
# 6835                      Closed     Lecture-Discussion       LCD   01:00 PM
# 6811           Open (Restricted)     Lecture-Discussion       LCD   01:00 PM
# 6809           Open (Restricted)     Lecture-Discussion       LCD   01:00 PM
#
#       End Time Days of Week  Room                        Building  \
# 6824  06:50 PM            M    46  Grad Sch of Lib & Info Science
# 6687  10:50 AM            R    18   Campus Instructional Facility
# 6673  01:50 PM            R   312               David Kinley Hall
# 6745       NaN          NaN   NaN                             NaN
# 6897       NaN          NaN   NaN                             NaN
# 6854       NaN          NaN   NaN                             NaN
# 6850  08:00 PM            R   NaN                             NaN
# 6804  08:00 PM            R   NaN                             NaN
# 6713  10:50 AM            F    53  Grad Sch of Lib & Info Science
# 6749  12:50 PM            W   NaN                             NaN
# 6705  08:50 AM            F   143                          Armory
# 6667  01:50 PM            R   126  Grad Sch of Lib & Info Science
# 6830  04:50 PM            R    46  Grad Sch of Lib & Info Science
# 6851  06:50 PM            M   131  Grad Sch of Lib & Info Science
# 6881  06:55 PM            W   NaN                             NaN
# 6726  12:50 PM           MW   NaN                             NaN
# 6668  01:50 PM            R   126  Grad Sch of Lib & Info Science
# 6690  12:20 PM            R   315                    Gregory Hall
# 6754  06:55 PM            W   NaN                             NaN
# 6688  10:50 AM            R   209                       Huff Hall
# 6741  11:50 AM          MWF  4036   Campus Instructional Facility
# 6807  06:55 PM            M   NaN                             NaN
# 6835  03:50 PM            W   131  Grad Sch of Lib & Info Science
# 6811  03:50 PM            M   126  Grad Sch of Lib & Info Science
# 6809  03:50 PM            W   147                          Armory
#
#                Instructors
# 6824           Takazawa, A
# 6687                Das, T
# 6673             Pintar, J
# 6745             Wolske, M
# 6897              Lucht, K
# 6854             Hodson, R
# 6850             Oliver, M
# 6804         Rangarajan, A
# 6713           Batzloff, B
# 6749          Underwood, W
# 6705         Sanfilippo, M
# 6667             Newell, M
# 6830               Song, Y
# 6851  Revell, Z;Woodard, B
# 6881        Butt, E;Koh, K
# 6726              Evans, C
# 6668             Newell, M
# 6690             Bygari, R
# 6754             Dahlen, S
# 6688                 Qu, T
# 6741            Cordell, R
# 6807            Alvarez, B
# 6835              Teper, J
# 6811               Chin, J
# 6809              Rusch, A
#
# [25 rows x 27 columns]

# %% [markdown]
# ### ✔️ Checkpoint ✔️
#
# There is no test cases for Part 4 (since everyone has different majors), but go double check your work!  There's just one section left to go! :)

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 5: Growth of the IS major
#
# The IS major is a new relatively new major here at UIUC.  The final puzzle is for you to analyze how much the IS major has grown since 2019.

# %% [markdown]
# ### Puzzle 5.1: Loading the Course Catalog Dataset from 2019
#
# Using the name `df2019` instead of `df`, load the "Fall 2019 Course Catalog Dataset" that can be found at the following URL:
# ```
# https://waf.cs.illinois.edu/discovery/course-catalog-fa19.csv
# ```

# %%
df2019 = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog-fa19.csv")
df2019
# Out:
#       Year  Term YearTerm Subject  Number  \
# 0     2019  Fall  2019-fa     AAS     100
# 1     2019  Fall  2019-fa     AAS     105
# 2     2019  Fall  2019-fa     AAS     120
# 3     2019  Fall  2019-fa     AAS     199
# 4     2019  Fall  2019-fa     AAS     200
# ...    ...   ...      ...     ...     ...
# 8584  2019  Fall  2019-fa    ZULU     202
# 8585  2019  Fall  2019-fa    ZULU     403
# 8586  2019  Fall  2019-fa    ZULU     404
# 8587  2019  Fall  2019-fa    ZULU     405
# 8588  2019  Fall  2019-fa    ZULU     406
#
#                                        Name  \
# 0              Intro Asian American Studies
# 1     Introduction to Arab American Studies
# 2             Intro to Asian Am Pop Culture
# 3                Undergraduate Open Seminar
# 4                      U.S. Race and Empire
# ...                                     ...
# 8584                     Elementary Zulu II
# 8585                    Intermediate Zulu I
# 8586                   Intermediate Zulu II
# 8587                        Advanced Zulu I
# 8588                       Advanced Zulu II
#
#                                             Description   Credit Hours  \
# 0     Interdisciplinary introduction to the basic co...       3 hours.
# 1     Interdisciplinary introduction to the basic co...       3 hours.
# 2     Introductory understanding of the way U.S. pop...       3 hours.
# 3              May be repeated to a maximum of 6 hours.  1 TO 5 hours.
# 4     Invites students to examine histories and narr...       3 hours.
# ...                                                 ...            ...
# 8584  Continuation of ZULU 201 with introduction of ...       5 hours.
# 8585  Survey of more advanced grammar; emphasis on i...       4 hours.
# 8586  Continuation of ZULU 403; emphasis on increasi...       4 hours.
# 8587  Third year Zulu with emphasis on conversationa...       3 hours.
# 8588  Continuation of Zulu 405 with increased emphas...       3 hours.
#
#                                            Section Info  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                      Same as LLS 200.
# ...                                                 ...
# 8584  Same as AFST 252. Participation in the languag...
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
#                                       Degree Attributes
# 0     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 1                Cultural Studies - US Minority course.
# 2                Cultural Studies - US Minority course.
# 3                                                   NaN
# 4     Humanities - Hist & Phil, and Cultural Studies...
# ...                                                 ...
# 8584                                                NaN
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
# [8589 rows x 10 columns]

# %% [markdown]
# ### Puzzle 5.2: Data Science Analysis
#
# In the following cells,
# - Select only the rows from the `IS` subject from the `df2019` dataset,
# - Select only the rows from the `IS` subject from the `df` dataset (this contains the 2022 data),
# - Complete the reflection question below (Puzzle 5.3).  Feel free to write more code to answer it.

# %%
df2019= df2019[df2019.Subject == "IS"]
df2019
# Out:
#       Year  Term YearTerm Subject  Number  \
# 4843  2019  Fall  2019-fa      IS     107
# 4844  2019  Fall  2019-fa      IS     199
# 4845  2019  Fall  2019-fa      IS     202
# 4846  2019  Fall  2019-fa      IS     310
# 4847  2019  Fall  2019-fa      IS     351
# ...    ...   ...      ...     ...     ...
# 4930  2019  Fall  2019-fa      IS     591
# 4931  2019  Fall  2019-fa      IS     592
# 4932  2019  Fall  2019-fa      IS     593
# 4933  2019  Fall  2019-fa      IS     594
# 4934  2019  Fall  2019-fa      IS     599
#
#                                              Name  \
# 4843                       Data Science Discovery
# 4844                   Undergraduate Open Seminar
# 4845                     Social Aspects Info Tech
# 4846                  Computing in the Humanities
# 4847  The Design of Usable Information Interfaces
# ...                                           ...
# 4930                                    Practicum
# 4931                            Independent Study
# 4932                                  CAS Project
# 4933                Information Sciences Practice
# 4934                              Thesis Research
#
#                                             Description    Credit Hours  \
# 4843          Same as CS 107 and STAT 107. See STAT 107        4 hours.
# 4844       Undergraduate Open Seminar. May be repeated.   1 TO 5 hours.
# 4845       Same as INFO 202 and MACS 202. See INFO 202.        3 hours.
# 4846  Explores use and application of technology to ...        3 hours.
# 4847  Examines issues of Human Computer Interaction ...        3 hours.
# ...                                                 ...             ...
# 4930  Supervised field experience of professional-le...        2 hours.
# 4931  Permits the intermediate or advanced student o...   2 TO 4 hours.
# 4932  Individual study of a problem in library and i...   0 TO 8 hours.
# 4933  Full-time or part-time practice of of any info...        0 hours.
# 4934  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info  \
# 4843          Same as CS 107 and STAT 107. See STAT 107
# 4844                                                NaN
# 4845       Same as INFO 202 and MACS 202. See INFO 202.
# 4846                                                NaN
# 4847                  Prerequisite: Sophomore standing.
# ...                                                 ...
# 4930  2 graduate hours. No professional credit. Appr...
# 4931  2 to 4 graduate hours. No professional credit....
# 4932  0 to 8 graduate hours. No professional credit....
# 4933  0 graduate hours. No professional credit. Appr...
# 4934  0 to 16 graduate hours. No professional credit...
#
#                        Degree Attributes
# 4843    Quantitative Reasoning I course.
# 4844                                 NaN
# 4845  Social & Beh Sci - Soc Sci course.
# 4846                                 NaN
# 4847                                 NaN
# ...                                  ...
# 4930                                 NaN
# 4931                                 NaN
# 4932                                 NaN
# 4933                                 NaN
# 4934                                 NaN
#
# [92 rows x 10 columns]

# %%
df = df[df.Subject == "IS"]
df
# Out:
#       Year  Term YearTerm Subject  Number  \
# 6663  2022  Fall  2022-fa      IS     100
# 6664  2022  Fall  2022-fa      IS     100
# 6665  2022  Fall  2022-fa      IS     100
# 6666  2022  Fall  2022-fa      IS     100
# 6667  2022  Fall  2022-fa      IS     100
# ...    ...   ...      ...     ...     ...
# 6907  2022  Fall  2022-fa      IS     596
# 6908  2022  Fall  2022-fa      IS     597
# 6909  2022  Fall  2022-fa      IS     597
# 6910  2022  Fall  2022-fa      IS     597
# 6911  2022  Fall  2022-fa      IS     599
#
#                                                    Name  \
# 6663   Exploring the iSchool with a Human-Centered Lens
# 6664   Exploring the iSchool with a Human-Centered Lens
# 6665   Exploring the iSchool with a Human-Centered Lens
# 6666   Exploring the iSchool with a Human-Centered Lens
# 6667   Exploring the iSchool with a Human-Centered Lens
# ...                                                 ...
# 6907  Advanced Topics in Human-Centered Design &amp;...
# 6908  Advanced Topics in Data Analytics &amp; Data S...
# 6909  Advanced Topics in Data Analytics &amp; Data S...
# 6910  Advanced Topics in Data Analytics &amp; Data S...
# 6911                                    Thesis Research
#
#                                             Description    Credit Hours  \
# 6663  This course introduces students to the School ...        1 hours.
# 6664  This course introduces students to the School ...        1 hours.
# 6665  This course introduces students to the School ...        1 hours.
# 6666  This course introduces students to the School ...        1 hours.
# 6667  This course introduces students to the School ...        1 hours.
# ...                                                 ...             ...
# 6907  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6908  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6909  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6910  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6911  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info Degree Attributes  \
# 6663  Prerequisite: Restricted to Majors Only; First...               NaN
# 6664  Prerequisite: Restricted to Majors Only; First...               NaN
# 6665  Prerequisite: Restricted to Majors Only; First...               NaN
# 6666  Prerequisite: Restricted to Majors Only; First...               NaN
# 6667  Prerequisite: Restricted to Majors Only; First...               NaN
# ...                                                 ...               ...
# 6907  2 or 4 graduate hours. No professional credit....               NaN
# 6908  2 or 4 graduate hours. No professional credit....               NaN
# 6909  2 or 4 graduate hours. No professional credit....               NaN
# 6910  2 or 4 graduate hours. No professional credit....               NaN
# 6911  0 to 16 graduate hours. No professional credit...               NaN
#
#       ... Section Status           Enrollment Status                Type  \
# 6663  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6664  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6665  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6666  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# 6667  ...              A  CrossListOpen (Restricted)  Lecture-Discussion
# ...   ...            ...                         ...                 ...
# 6907  ...              A           Open (Restricted)              Online
# 6908  ...              A           Open (Restricted)  Lecture-Discussion
# 6909  ...              A           Open (Restricted)  Lecture-Discussion
# 6910  ...              A           Open (Restricted)              Online
# 6911  ...              A           Open (Restricted)   Independent Study
#
#      Type Code Start Time  End Time Days of Week Room  \
# 6663       LCD   09:30 AM  10:50 AM            T  126
# 6664       LCD   09:30 AM  10:50 AM            T  126
# 6665       LCD   02:00 PM  03:20 PM            R  126
# 6666       LCD   02:00 PM  03:20 PM            R  126
# 6667       LCD   01:00 PM  01:50 PM            R  126
# ...        ...        ...       ...          ...  ...
# 6907       ONL   01:00 PM  02:55 PM            M  NaN
# 6908        S1   09:00 AM  11:50 AM            M  131
# 6909        S2   09:00 AM  11:50 AM            W  126
# 6910       ONL   09:00 AM  10:55 AM            F  NaN
# 6911       IND   ARRANGED       NaN          NaN  NaN
#
#                             Building Instructors
# 6663  Grad Sch of Lib & Info Science   Newell, M
# 6664  Grad Sch of Lib & Info Science   Newell, M
# 6665  Grad Sch of Lib & Info Science   Newell, M
# 6666  Grad Sch of Lib & Info Science   Newell, M
# 6667  Grad Sch of Lib & Info Science   Newell, M
# ...                              ...         ...
# 6907                             NaN     Wang, D
# 6908  Grad Sch of Lib & Info Science   Weible, J
# 6909  Grad Sch of Lib & Info Science   Weible, J
# 6910                             NaN  Diesner, J
# 6911                             NaN         NaN
#
# [249 rows x 27 columns]

# %%
# Feel free to add more code cells if needed by hovering over the area below the cell and pressing "+ Code"!

# %% [markdown]
# ### Puzzle 5.3: Reflection on the Growth of Information Science
#
# In the follow cell, write **at least one complete sentence explaining what you found** related to the growth of the IS program.  In your answer, **use actual data** (ex: by how much did it grow?)

# %% [markdown]
# Between the recent data and 2019 is that new course has been added and to countinue to be added.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission

# %% [markdown]
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
